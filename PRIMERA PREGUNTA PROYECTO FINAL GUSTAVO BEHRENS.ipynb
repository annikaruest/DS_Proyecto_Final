# %% [markdown]
# # PRIMERA PREGUNTA PROYECTO FINAL GUSTAVO BEHRENS

# %% [markdown]
# #  ¿Cuál es la edad que presenta la mayor probabilidad de ser ingresado al hospital como emergencia?

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as pl
import seaborn as sns

df= pd.read_csv(r"C:\Users\Gustavo\Documents\UFM\tercer semestre\data science\diabetes.csv")

print df
df.head()

df.info
df.readmitted.describe()
df.mode()
df.age.describe()
 
##cual es la edad que presenta la mayor probabilidad de ser ingresado al hospital como emergencia

# para calcular esto, dividiré los eventos favorables dentro los eventos posibles para calcular la 
#probabilidad de cada rango de edades
 
#filtrando de mi data frame, la variable age, especifico lo que quiero filtrar para enconttrar la frequencia.

df[(df.age == '[80-90)')&(df.admission_type_id == 1)].count()

from __future__ import division

EvFavo=df.encounter_id[(df.age == '[0-10)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[10-20)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

#tengo duda con este
EvFavo=df.encounter_id[(df.age == '[20-30)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[30-40)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[40-50)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[50-60)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[60-70)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[70-80)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

EvFavo=df.encounter_id[(df.age == '[80-90)')&(df.admission_type_id == 1)].count()
EvPos=df.encounter_id[df.admission_type_id == 1].count()
probabilidad = str((EvFavo/EvPos)*100) + '%'
print probabilidad

Resultados
#0-10:  0.194480459344%
#10-20  0.818670124097%
#20-30  1.7429153547%
#30-40  3.83589553621%
#40-50  9.74069272087%
#50-60  16.497499537%
#60-70   20.6482681978%
#70-80   24.956473421%
#80-90   18.2959807372%

#de 70-80 es la edad que presenta payr probabilidad ha ser ingresados de emergencia a la hora de ser
#ingresados.
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)      ?
# 1             149190     55629189        Caucasian  Female   [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3             500364     82442376        Caucasian    Male   [30-40)      ?
# 4              16680     42519267        Caucasian    Male   [40-50)      ?
# 5              35754     82637451        Caucasian    Male   [50-60)      ?
# 6              55842     84259809        Caucasian    Male   [60-70)      ?
# 7              63768    114882984        Caucasian    Male   [70-80)      ?
# 8              12522     48330783        Caucasian  Female   [80-90)      ?
# 9              15738     63555939        Caucasian  Female  [90-100)      ?
# 10             28236     89869032  AfricanAmerican  Female   [40-50)      ?
# ...

# %% [markdown]
# ## RESPUESTA: LAS PERSONAS DE 70-80 AÑOS PRESENTAN LA MAYOR PROBABILIDAD DE SER INGRESADOS AL HOSPITAL DE CARACTER DE EMERGENCIA.
